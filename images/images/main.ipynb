# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import pytesseract

# %%
pytesseract.pytesseract.tesseract_cmd = "C:\\Program Files\\Tesseract-OCR\\tesseract.exe"
print(pytesseract.image_to_data("./sample_tensors/51KykmLgc0L.jpg"))

# %%
import easyocr
import cv2
import matplotlib.pyplot as plt

# Initialize the easyocr reader (specify languages you want to recognize)
reader = easyocr.Reader(['en'])

# Load your image
image_path = './sample_tensors/51r7U52rh7L.jpg'  # Specify the path to your image
image = cv2.imread(image_path)

# Extract text from the image
results = reader.readtext(image_path)

# Display the image
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# Print the extracted text
for (bbox, text, prob) in results:
    print(f"{text} (Confidence: {prob:.2f})")
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ...
